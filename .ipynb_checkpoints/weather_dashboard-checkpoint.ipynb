# %%
import streamlit as st
import requests
import matplotlib.pyplot as plt

# API Key
api_key = "10b0b3741256c3d840ad164ba3cba2c8"

# Function to fetch weather for a city
def get_weather(city):
    url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={api_key}&units=metric"
    data = requests.get(url).json()
    return {
        'City': city,
        'Temp': data['main']['temp'],
        'Humidity': data['main']['humidity'],
        'Wind': data['wind']['speed'],
        'Weather': data['weather'][0]['description']
    }

# Top cities or user can select multiple
all_cities = ['Kolkata', 'Mumbai', 'Delhi', 'Bengaluru', 'Chennai', 'Hyderabad', 'Pune', 'Ahmedabad', 'Jaipur', 'Lucknow']

st.title("🌤️ Real-Time Weather Dashboard")

# Multi-select widget for cities
selected_cities = st.multiselect("Select Cities to Compare:", all_cities, default=['Kolkata', 'Mumbai'])

weather_data = [get_weather(city) for city in selected_cities]

# Show raw data
st.subheader("Weather Data")
st.write(weather_data)

# Plot Temperature Comparison
st.subheader("🌡️ Temperature Comparison")
cities = [d['City'] for d in weather_data]
temps = [d['Temp'] for d in weather_data]

fig, ax = plt.subplots()
ax.bar(cities, temps, color='orange')
ax.set_ylabel("Temperature (°C)")
ax.set_title("Temperature Across Cities")
st.pyplot(fig)

# Plot Humidity Comparison
st.subheader("💧 Humidity Comparison")
humidity = [d['Humidity'] for d in weather_data]

fig2, ax2 = plt.subplots()
ax2.bar(cities, humidity, color='skyblue')
ax2.set_ylabel("Humidity (%)")
ax2.set_title("Humidity Across Cities")
st.pyplot(fig2)

# Optional: show Wind
st.subheader("💨 Wind Speed")
wind = [d['Wind'] for d in weather_data]
for d in weather_data:
    st.write(f"{d['City']}: {d['Wind']} m/s, {d['Weather']}")
# Out:
# 2025-09-10 01:14:42.460 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-10 01:14:42.461 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-10 01:14:42.463 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-10 01:14:42.464 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-10 01:14:42.468 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-10 01:14:42.468 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-10 01:14:42.470 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-10 01:14:42.470 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-10 01:14:42.472 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-10 01:14:42.716 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-10 01:14:42.716 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-10 01:14:42.724 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-10 01:14:45.107 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-10 01:14:45.107 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-10 01:14:45.118 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-10 01:14:45.118 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-10 01:14:45.118 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-10 01:14:45.121 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-10 01:14:45.223 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-10 01:14:45.608 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-10 01:14:45.608 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-10 01:14:45.608 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-10 01:14:45.614 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-10 01:14:45.614 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-10 01:14:45.614 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-10 01:14:45.642 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-10 01:14:45.989 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-10 01:14:45.989 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-10 01:14:45.989 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-10 01:14:45.989 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-10 01:14:45.989 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-10 01:14:45.989 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-10 01:14:45.989 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-10 01:14:45.989 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-10 01:14:45.997 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-10 01:14:45.997 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-10 01:14:45.997 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-10 01:14:45.997 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# !streamlit run weather_dashboard.py
# Out:
# Usage: streamlit run [OPTIONS] TARGET [ARGS]...
# Try 'streamlit run --help' for help.
#
# Error: Invalid value: File does not exist: weather_dashboard.py

# %%
"execution_count": None
# Out:
#   Cell In[6], line 1
#     "execution_count": None
#     ^
# SyntaxError: illegal target for annotation
